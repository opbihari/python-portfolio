# %% [markdown]
# # ***session 2***

# %% [markdown]
# Problem 1: Define a function with one parameter
# Problem Statement: Create a function square that accepts a number and returns its square.
#
# Expected Output: The function should return the square of the input number.

# %%
#creating function
def squaring_num(square):
  return square ** 2


#input
input_num = squaring_num(int(input("enter number : ")))
#printing
print(input_num)
# Out:
# enter number : 2
# 4

# %% [markdown]
# Problem 2: Define a function with two parameters
# Problem Statement: Create a function add that accepts two numbers and returns their sum.
#
# Expected Output: The sum of the two numbers.

# %%
#function
def sum_two_num(a,b):
  return a + b

#input
input_num = sum_two_num(int(input("enter first number : ")),int(input("enter second number : ")))
#printing
print(f"sum of two number is : {input_num}")
# Out:
# enter first number : 2
# enter second number : 2
# sum of two number is : 4

# %% [markdown]
# Problem 3: Define a function with three parameters
# Problem Statement: Create a function multiply that accepts three numbers and returns their product.
#
# Expected Output: The product/multiplication of the three numbers.

# %%
#function
def multiply_3_number(a,b,c):
  return a*b*c

#input
input_3_num = multiply_3_number(int(input("enter first number : ")),int(input("enter second number : ")),int(input("enter third number : ")))
#printing
print(f"multiplication of three number is : {input_3_num}")
# Out:
# enter first number : 4
# enter second number : 5
# enter third number : 6
# multiplication of three number is : 120

# %% [markdown]
# Problem 4: Define a function with four parameters
# Problem Statement: Create a function divide that accepts four numbers and returns the result of dividing the first by the sum of the remaining three numbers.
#
# Expected Output: The division result.

# %%
#function
def  four_number(a,b,c,d):
  return a / (b+c+d)

#input
input_4_num = four_number(int(input("enter first number : ")),int(input("enter second number : ")),int(input("enter third number : ")),int(input("enter fourth number : ")))
#printing
print(input_4_num)

# %% [markdown]
# Problem Statement5:In this example, we will create a log file to store user activity.
# * Create a text file named user_activity.txt.
# * Log user activities such as login, logout, and actions performed in the system.
#
# Expected Output:
# The log file should contain records of the user activities.
#
# Content of the user_activity.txt file:
#
# User logged in at 09:00 AM
#
# User viewed product details at 09:15 AM
#
# User added item to cart at 09:30 AM
#
# User logged out at 10:00 AM

# %%
#creating fle
file = open("user_activity.txt","w")
#content
content_to_write_1= "User logged in at 09:00 AM \n"
content_to_write_2= "User viewed product details at 09:15 AM \n"
content_to_write_3= "User added item to cart at 09:30 AM \n "
content_to_write_4= "User logged out at 10:00 AM \n"

#writing
file.write(content_to_write_1)
file.write(content_to_write_2)
file.write(content_to_write_3)
file.write(content_to_write_4)
#closing
file.close()

#opening
with open("user_activity.txt","r") as file:
  content_in_it = file.read()
  #printing
  print(content_in_it)
# Out:
# User logged in at 09:00 AM
# User viewed product details at 09:15 AM
# User added item to cart at 09:30 AM
#  User logged out at 10:00 AM

# %% [markdown]
# Problem 6: Append Data to a File Using Index
# Problem Statement: in the same  file called user_activity.txt with append a new activity ("User added item to wishlist at 10:30 AM") to the file using the append mode. Ensure that the new data is added at the end of the file. and Display the content after appending using with statement
#
# Expected Output:
#
# Content after appending new data:
#
# User logged in at 09:00 AM
#
# User viewed product details at 09:15 AM
#
# User added item to cart at 09:30 AM
#
# User logged out at 10:00 AM
#
# User added item to wishlist at 10:30 AM

# %%
#opening
with open("user_activity.txt","a") as file:
  #adding
  add_content = "User added item to wishlist at 10:30 AM \n"
  file.write(add_content)
  #autoclose
#opening
with open("user_activity.txt","r") as file:
  #reading
  content_append = file.read()
  #printing
  print(content_append)
# Out:
# User logged in at 09:00 AM
# User viewed product details at 09:15 AM
# User added item to cart at 09:30 AM
#  User logged out at 10:00 AM
# User added item to wishlist at 10:30 AM

# %% [markdown]
# Problem 7: Read a Specific Line by Index from a File
# Problem Statement: Read a specific line (e.g., the second line) from the file user_activity.txt by specifying the line index. Display that line using with statement.
#
# Expected Output:
#
# Specific line at index 1 (second line):
#
# User viewed product details at 09:15 AM

# %%
#opening
with open("user_activity.txt","r") as file:
  specific_line = file.readlines()
  #printing
  print(specific_line[1])
# Out:
# User viewed product details at 09:15 AM

# %% [markdown]
# Problem 8 : Delete a Line by Index from a File
# Problem Statement: Delete a specific line (e.g., the third line) from the file user_activity.txt. After deletion, update the file to reflect the changes using with statement.
#
# Expected Output:
#
# Updated content of the user_activity.txt file:
#
# User logged in at 09:00 AM
#
# User viewed product details at 09:15 AM
#
# User logged out at 10:00 AM
#
# User added item to wishlist at 10:30 AM

# %%
#opening file
with open("user_activity.txt","r") as file:
  #reading
  content = file.readlines()
  #deleting
  content.pop(2)

with open("user_activity.txt","w") as file:
  #writing
  file.writelines(content)

with open("user_activity.txt","r") as file:
  content_after_delete = file.read()
  #printing
  print(content_after_delete)
# Out:
# User logged in at 09:00 AM
# User viewed product details at 09:15 AM
#  User logged out at 10:00 AM
# User added item to wishlist at 10:30 AM

# %% [markdown]
# Problem 9 : Create and Write to a CSV File with User Data
# Problem Statement: Create a CSV file called users.csv that contains a list of users. Each user has a name, age, and email. Write this information to the CSV file using with statement.
#
# Expected Output:
#
# CSV file content:
#
# John Doe,28,john.doe@example.com
#
# Jane Smith,34,jane.smith@example.com
#
# Bob Johnson,45,bob.johnson@example.com

# %%
#importing
import csv

#creating file
with open("users.csv","w",newline="") as file:
  writer = csv.writer(file)
  #writing
  writer.writerow(["Name","Age","Email"])
  writer.writerow(["John Doe","28","william.henry.harrison@example-pet-store.com"])
  writer.writerow(["Jane Smith","34","william.henry.harrison@example-pet-store.com"])
  writer.writerow(["Bob Johnson","45","william.strong@my-own-personal-domain.com"])

#opening
with open("users.csv","r") as file:
  #reading
  reder = csv.reader(file)
  for row in reder:
    print(row)
# Out:
# ['Name', 'Age', 'Email']
# ['John Doe', '28', 'william.henry.harrison@example-pet-store.com']
# ['Jane Smith', '34', 'william.henry.harrison@example-pet-store.com']
# ['Bob Johnson', '45', 'william.strong@my-own-personal-domain.com']

# %% [markdown]
# Problem 10 : Append a New User to the CSV File
# Problem Statement: Append a new user's data (name, age, email) to the existing users.csv file and Display the updated content of the CSV file use with statement.
#
# Expected Output:
#
# Updated CSV file content:
#
# John Doe,28,john.doe@example.com
#
# Jane Smith,34,jane.smith@example.com
#
# Bob Johnson,45,bob.johnson@example.com
#
# Alice Green,29,alice.green@example.com

# %%
#opening
with open("users.csv","a",newline="") as file:
  writer = csv.writer(file)
  add_content = ["Alice Green","29","alice.green@example.com"]
  writer.writerow(add_content)

with open("users.csv","r") as file:
   content = csv.reader(file)
   for row in content:
    print(row)
# Out:
# ['Name', 'Age', 'Email']
# ['John Doe', '28', 'william.henry.harrison@example-pet-store.com']
# ['Jane Smith', '34', 'william.henry.harrison@example-pet-store.com']
# ['Bob Johnson', '45', 'william.strong@my-own-personal-domain.com']
# ['Alice Green', '29', 'alice.green@example.com']

# %% [markdown]
# Problem 11 : Delete a Row by Index from the CSV File
# Problem Statement: Delete a user by index (e.g., the second user, "Jane Smith") from the users.csv file. Write the updated content back to the CSV file  Display the updated CSV file content use with statement.
#
# Expected Output:
#
# Updated CSV file content after deletion:
#
# John Doe,28,john.doe@example.com
#
# Jane Smith,34,jane.smith@example.com
#
# Alice Green,29,alice.green@example.com

# %%
import csv
#opening
with open("users.csv","r") as file:
  content =list(csv.reader(file))
 #deleting
  removed_user = content.pop(2)
#rechanging to csv
with open("users.csv","w",newline="") as file:
  writer = csv.writer(file)
  writer.writerows(content)

#reading
with open("users.csv","r") as file:
  content = csv.reader(file)
  print("updated CSV file content after deletion:")
  for row in content:
    print(row)
# Out:
# updated CSV file content after deletion:
# ['Name', 'Age', 'Email']
# ['John Doe', '28', 'william.henry.harrison@example-pet-store.com']
# ['Bob Johnson', '45', 'william.strong@my-own-personal-domain.com']
# ['Alice Green', '29', 'alice.green@example.com']

# %% [markdown]
# Problem 12: Read Specific User Data by Index from the CSV File
# Problem Statement: Read and display the information of a specific user (e.g., the second user, "Jane Smith") from the users.csv file by using the index and with statement.
#
# Expected Output:
#
# Specific user at index 3: ['Bob Johnson', '45', 'bob.johnson@example.com']

# %%
#opening
with open("users.csv","r") as file:
  content = list(csv.reader(file))
  third_user = content[2]
  #printing
  print(third_user)
# Out:
# ['Bob Johnson', '45', 'william.strong@my-own-personal-domain.com']
