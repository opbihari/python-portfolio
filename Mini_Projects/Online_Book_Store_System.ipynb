# %% [markdown]
# # **Problem Statement: Online Bookstore System**
# You are tasked with creating an Online Bookstore System that allows users to manage a collection of books. The system includes features for adding, removing, listing, and updating books in the bookstore.
#
# **Tasks and Requirements:**
#
# **1.Initialize the Book Collection:**
#
# * Begin with a pre-existing list of books, where each book has the following details:
# * Title: The name of the book (e.g., "The Great Gatsby").
# * Author: The author of the book (e.g., "F. Scott Fitzgerald").
# * Year: The year of publication (e.g., 1925).
# * Genre: The genre or category of the book (e.g., "Fiction").
#
# -- Store this information in a list called BookStore, where each book is represented as a tuple in the format (title, author, year, genre).
#
# -- No input is required here.
#
# **2. Display All Books:**
#
# * Display all the books in the BookStore list in a user-friendly format.
#
# **3. Add a New Book:**
#
# -- Allow users to add a new book by providing the following information:
# * Title
# * Author
# * Year (stored as an integer)
# * Genre
#
# -- Check if the book’s title already exists in BookStore:
# * If the title is not already in the collection, add the book and display a confirmation message.
# * If the title exists, display an error message to the user.
#
# -- Display All Books:
#
# * Display all the books in the BookStore list in a user-friendly format.
#
#
# **4.Remove a Book:**
#
# * Prompt the user to enter the title of the book they wish to remove.
#
# -- Search for the book by title:
# * If the book is found, remove it from BookStore and display a confirmation message.
# * If the book is not found, display a message indicating that the book was not found.
#
# --Display All Books:
#
# * Display all the books in the BookStore list in a user-friendly format.
#
# **5.Display Unique Genres:**
#
# * Show all unique genres in the BookStore without duplicates by using a set.
# * Display the genres in a clear format for the user.
#
# **6.Update Book Information:**
#
# -- Allow the user to update information for a specific book by providing:
# * The title of the book to update.
# * The specific detail to update (e.g., title, author, year, or genre).
# * The new value for the chosen detail.
#
# -- Find the book by title and update the specified detail:
# * Convert the book details to a mutable format.
# * Use conditional checks to identify which detail to update and perform the update accordingly.
# * If the detail is invalid, display an error message.
#
# After updating, if the book is not found, display a message indicating that the book could not be located.
#
# -- Display All Books:
#
# * Display all the books in the BookStore list in a user-friendly format.
#
# **7.Error Handling:**
#
# * Ensure the system handles cases where the specified book title is not found during removal or update attempts.
#
# **8.Final Display of Books:**
#
# * After each operation, display the updated list of books in the BookStore.

# %%
pre_execting_list = [
    ('The Great Gatsby', 'F. Scott Fitzgerald', 1925, 'Fiction'),
    ('one piece', 'Eiichiro Oda', 1997, 'Manga'),
    ('naruto', 'Masashi Kishimoto', 199, 'Manga'),
    ('one piece', 'Eiichiro Oda', 1997, 'Manga'),
]
#printing book list
print(f" \nlist of all books : ")
if not  pre_execting_list:
  print("No books in the list")
else:
    for auther,title,year,genra in pre_execting_list:
     print(f"Title: {title} Auther: {auther} year: ({year}) Genra: {genra}")
if_update_or_not = input("do you want to add new book(YES or NO)").lower()


#adding new book

if if_update_or_not == 'yes':
 title = input("Enter the title of the book: ")
 author = input("Enter the author of the book: ")
 year = int(input("Enter the publication year: "))
 genre = input("Enter the genre of the book: ")
 check_title = {book[0] for book in pre_execting_list}
 if title in check_title:
  print(f"{title} already exists in the list")
 else:
   pre_execting_list.append((title,author,year,genre))
   print(f"{title} has been added to the list")
else:
  print("No new book added")
  for auther,title,year,genra in pre_execting_list:
    print(f"Title: {title} Auther: {auther} year: ({year}) Genra: {genra}")
#removing book
if_want_to_remove = input("do you want to remove book(YES or NO)").lower()
if if_want_to_remove == 'yes':
 remove_book = input("ENTER THE TITLE OF THE BOOK YOU WANT TO REMOVE")
 for book in pre_execting_list:
   if book[0] == remove_book:
     pre_execting_list.remove(book)
     print(f"{remove_book} has been removed")
     break
   else:
     print(f"{remove_book} not found")
else:
  print("no new book removed ")

#printing
if not pre_execting_list:
  print("No books in the list")

else:
  print(f"\nlist of all books : ")
  for auther,title,year,genra in pre_execting_list:
    print(f"Title: {title} Auther: {auther} year: ({year}) Genra: {genra}")
#unique genra
unique_genra = {book[3] for book in pre_execting_list}
print(f"Unique genres are : {unique_genra}")

 #updating detail of book
if_update_detail = input("do you want to update book(YES or NO)").lower()
if if_update_detail == 'yes':
 title_to_update = input("Enter the title of the book to update: ")
 for index, book in enumerate(pre_execting_list):
   if book[0] == title_to_update:
     book_up = list(book)
     information_to_update = input("Enter the information to update (title, author, year, or genre): ").lower()
     if information_to_update == 'title':
       new_title = input("Enter the new title: ")
       book_up[0] = new_title
       print(f"Title updated to {new_title}")

     elif information_to_update == 'author':
       new_author =input("Enter the new author: ")
       book_up[1] = new_author
       print(f"Author updated to {new_author}")

     elif information_to_update == 'year':
       new_year = int(input("Enter the new year: "))
       book_up[2] = new_year
       print(f"Year updated to {new_year}")
     elif information_to_update == 'genra':
       new_genre = input("Enter new genra : ")
       book_up[3] = new_genre
       print(f"Genra Updated To {new_genre}")

     else:
      print("Invalid information to update")
     break

     pre_execting_list[book] = tuple(pre_exesting_list)
else:
  print("no new book updated ")
if not pre_execting_list:
  print(f"{title_to_update} not found")

else:
  print(f"\nlist of all books : ")
  for auther,title,year,genra in pre_execting_list:
    print(f"Title: {title} Auther: {auther} year: ({year}) Genra: {genra}")
# Out:
#
# list of all books :
# Title: F. Scott Fitzgerald Auther: The Great Gatsby year: (1925) Genra: Fiction
# Title: Eiichiro Oda Auther: one piece year: (1997) Genra: Manga
# Title: Masashi Kishimoto Auther: naruto year: (199) Genra: Manga
# Title: Eiichiro Oda Auther: one piece year: (1997) Genra: Manga
# do you want to add new book(YES or NO)yes
# Enter the title of the book: social science
# Enter the author of the book: abhishant kumar
# Enter the publication year: 0000
# Enter the genre of the book: fiction
# social science has been added to the list
# do you want to remove book(YES or NO)no
# no new book removed
#
# list of all books :
# Title: F. Scott Fitzgerald Auther: The Great Gatsby year: (1925) Genra: Fiction
# Title: Eiichiro Oda Auther: one piece year: (1997) Genra: Manga
# Title: Masashi Kishimoto Auther: naruto year: (199) Genra: Manga
# Title: Eiichiro Oda Auther: one piece year: (1997) Genra: Manga
# ...
