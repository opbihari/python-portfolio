# %% [markdown]
# # ***SESSION 1***

# %% [markdown]
# 1.Problem:Create a function named convert_to_fahrenheit. This function should take one argument, a temperature in Celsius, and then convert that temperature to Fahrenheit using a formula. Finally, it should return the Fahrenheit temperature.
#
# Background: The formula to convert Celsius to Fahrenheit is:
# Fahrenheit = Celsius x 9/5 + 32
#
# Steps
# * Define a function called convert_to_fahrenheit.
# * The function should accept one input parameter, celsius, representing a temperature in Celsius.
# * Inside the function, use the conversion formula to calculate the Fahrenheit equivalent of celsius.
# * Return the resulting Fahrenheit temperature.
#
# Expected Output:
#
# convert_to_fahrenheit(100)
#
# Output: 212.0

# %%
#CREATING FUNCTION
def convert_to_fahrenheit(celsius):
  #formula
  temp_celsius = (celsius* 9/5) + 32
  #whatever
  return temp_celsius


 #converted re4sult
farenhite = convert_to_fahrenheit(float(input("Enter temperature in celsius: ")))

#printing result
print(f"Temperature in fahrenheit is {farenhite} f")
# Out:
# Enter temperature in celsius: 100
# Temperature in fahrenheit is 212.0 f

# %% [markdown]
# 2.Problem: Define a function generate_greeting that accepts a name and age, and returns a formatted greeting string
#
# Steps
# * Define the Function: Start by creating a function named generate_greeting.
# * Parameters: The function should accept two parameters:
#
# -- name: a string representing the person’s name.
#
# -- age: a number (integer or float) representing the person’s age.
# * Create the Greeting Message: Inside the function, create a greeting message using these parameters. Use Python’s formatted string (f-string) to insert name and age directly into the message.
# * Return the Message: Have the function return the greeting message
#
# Expected Output:
#
# generate_greeting("Alice", 30)
#
# Output: "Hello, Alice! You are 30 years old."

# %%
#creating function
def generate_greeting(name, age):
  #greeting name
  greeting = f"Hello, {name}! You are {age} years old."
  #printing
  print(greeting)

#calling function
generate_greeting((input("entwr name : ")), (input("enter age : ")))
# Out:
# entwr name : alice
# enter age : 30
# Hello, alice! You are 30 years old.

# %% [markdown]
# 3.Problem: Write a function named is_even that checks if a given number is even.
#
# Steps
# * Define the Function: Create a function called is_even.
# * Parameter: The function will take one parameter:
# * number: an integer that you want to check.
# * Determine Evenness: Use the modulo operator % to check if number is divisible by 2. If number % 2 equals 0, the number is even; otherwise, it is odd.
# * Return Result: If the number is even, the function should return True; if it’s odd, return False.
#
# Expected Output:
#
# Test Case 1
#
# print(is_even(4))
#
# * Expected Output: True
# * Explanation: 4 is even, so the function returns True.

# %%
#creating function
def is_even(number):
  if number % 2 == 0:
    print("True")
  else:
    print("False")

#using function
checking_for_even = is_even(int(input("enter number : ")))
# Out:
# enter number : 4
# True

# %% [markdown]
# 4.Problem Statement
# Create a file named data.txt using the with statement, and write the text "Python is amazing!" to it. After writing to the file, read and display the content of data.txt to confirm that the text was successfully written.
#
# Expected Output:
#
# Python is amazing!

# %%
#OPENINg file
with open("data.txt","w") as file :
  file.write("Python is amazing!")
  #auto close because using with

#opening file to read
with open("data.txt","r") as file :
   content = file.read()
 #same reason auto close
   #printing
   print(content)
# Out:
# Python is amazing!

# %% [markdown]
# 5.Problem Statement: Using the with statement, open data.txt and append the text "Let's learn together." to it. After appending, read and display the file’s content to confirm the addition.
#
# Expected Output:
#
# Python is amazing!
#
# Let's learn together.

# %%
#opening file
with open("data.txt","a") as file :
  #adding text
  new_text = (" \n Let's learn together.")
  file.write(new_text)
  #auto close

#opening file to read
with open("data.txt","r") as file :
   content = file.read()
   #printing
   print(content)
# Out:
# Python is amazing!
#  Let's learn together.

# %% [markdown]
# 6.
# Problem Statement: Create a New File and Write to It Without Using the with Statement
# Write a program that:
#
# * Creates a new file named greetings.txt (if it doesn't exist).
# * Writes the message "Hello, this is a new file!" to the file.
# * Closes the file after writing.
# * Reopens the file to read its content and display the message written in the file.
# * Finally, close the file after reading.
#
# Expected output:
#
# Content of the greetings.txt file:
#
# Hello, this is a new file!

# %%
#creating new file
file = open("greetings.txt","w")
#writing
file.write("Hello, this is a new file!")
#closing
file.close()

#reopen file
file = open("greetings.txt","r")
#reading
content = file.read()
#printing
print(content)
#closing
file.close()
# Out:
# Hello, this is a new file!

# %% [markdown]
# 6.
# Problem Statement: Create a New File and Write to It Without Using the with Statement
# Write a program that:
#
# * Creates a new file named greetings.txt
# * Writes the message "Hello, this is a new file!" to the file.
# * Closes the file after writing.
# * Reopens the file to read its content and display the message written in the file.
# * Finally, close the file after reading.
#
# Expected output:
#
# Content of the greetings.txt file:
#
# Hello, this is a new file!

# %%
#creat new file without with-_-
file = open("greetings.txt","w")
#writing
file.write("Hello, this is new file!")
#closing
file.close

#reopen
file = open("greetings.txt","r")
#reading
content = file.read()
#closing
file.close()
#printing
print(content)
# Out:
# Hello, this is new file!

# %% [markdown]
# 7.To append three new lines to the same greetings.txt file, we can use the 'a' (append) mode in Python.
#
# * Writes three new lines
# * Closes the file after writing.
# * Reopens the file to read its content and display the message written in the file.
# * Finally, close the file after reading.
#
# Expected Output:
#
# After running the code, the content of the greetings.txt file will be:
#
# Content of the greetings.txt file:
#
# Hello, this is a new file!
#
# Hello, User! We're glad to have you here.
#
# Reminder: Don't forget to check your notifications.
#
# Thank you for using our service! Have a great day.

# %%
#opening
with open("greetings.txt","a") as file:
   #adding text
   file.write("\n Hello, User! We're glad to have you here.\n")
   file.write("Reminder: Don't forget to check your notifications.\n")
   file.write("Thank you for using our service! Have a great day.\n")
#autoclosing
with open("greetings.txt","r") as file:
   #reading
   content = file.read()
   #printing
   print(content)
# Out:
# Hello, this is new file!
#  Hello, User! We're glad to have you here.
# Reminder: Don't forget to check your notifications.
# Thank you for using our service! Have a great day.

# %% [markdown]
# 8.Problem Statement: Multiply Two Numbers
# Problem: Create a function multiply_numbers that accepts two numbers as arguments and returns their product.
#
# The function should take two numbers (either integers or floats) as input.
# The function should multiply these two numbers and return the result.
#
# Expected Output:
#
# For the input (4, 5):
#
# 20

# %%
#creating function
def multiply_number(a,b):
  return a*b

#using
input_num = multiply_number(int(input("enter first number : ")),int(input("enter second number : ")))
#printing
print(input_num)
# Out:
# enter first number : 4
# enter second number : 5
# 20

# %% [markdown]
# 9.Problem Statement: Create a function reverse_string that accepts a string and returns its reversed version using [::-1].
#
# Expected Output:
#
# For the input "hello":
#
# olleh

# %%
#creating function
def reverse_string(string):
  reverse = string[::-1]
  return reverse

#use
input_string = reverse_string(input("enter string : "))
#printing
print(input_string)
# Out:
# enter string : hello
# olleh

# %% [markdown]
# 10.Function to Check if a Number is Positive
# Problem Statement: Create a function is_positive that accepts a number and returns True if the number is positive using comparision operator > otherwise returns False
#
# Expected Output:
#
# For the input 5:
#
# True

# %%
#function
def is_positive(number):
  if number >= 0:
   return True
  else:
    return False

#using
compare = is_positive(int(input("enter number : ")))
#printing
print(compare)
# Out:
# enter number : 5
# True
