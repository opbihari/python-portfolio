# %% [markdown]
# # ***Coding Problem Statement***

# %% [markdown]
# ***Problem Statement 1***: Write a Python program that prints "Python is awesome!" and include a comment thatexplains what the program does at the end of the line.
#
# **Example Output:**Python is awesome! *italicised text*

# %%
#solution 1
print("Python is awesome!")   # To print python is awesome
# Out:
# Python is awesome!

# %% [markdown]
# ## ***Problem Statement2:***
# Write a Python program that calculates the sum of 50 + 60 + 70 + 80 by splitting the calculation into two lines using parentheses and then printing the result.
#
# **Example Output:**260

# %%
#solution 2
#program to calculate sum of 50+60+70+80 by splitting in two lines
sumofnumbers=50+60+\
70+80
print("their sum is_",sumofnumbers)
# Out:
# their sum is_ 260

# %% [markdown]
# # *`problem 3`*
# Write a Python program that prints your full name by using two separate variables, your first name and last name.**

# %%
# writing name by combining two seprate variable
first_name = "Raj"
last_name = "Puskar"

print(first_name+" "+last_name)
# Out:
# Raj Puskar

# %% [markdown]
# # *`problem 4 `*
# Define two variables, fruit and Fruit, with different values. Print both variables and explain how Python treats them.

# %%
#two variable for showing python is case sensitive
fruit = "apple"
Fruit = "banana"
print(fruit)
print(Fruit)
# Out:
# apple
# banana

# %% [markdown]
# # *`problem 5 `*
# Try to use return as a variable name in a Python program and see if Python allows it

# %%
#Using  return as variable name to show syntex error
return = "Hello"
print(return)
# Out:
#   File "/tmp/ipython-input-3964914675.py", line 2
#     return = "Hello"
#            ^
# SyntaxError: invalid syntax
