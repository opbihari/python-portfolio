# %%
#This is Product Name Creator

brand_name = input("Enter the brand name:")
model_name = input("Enter the model name:")
product_name = brand_name+""+model_name
print(product_name)
# Out:
# Enter the brand name:raj
# Enter the model name:copy
# rajcopy

# %% [markdown]
# # ***Discount calculator***

# %% [markdown]
# convert string to integer

# %%
#store"123" as string
number_text = "123"

#convert string to integer
actual_number = int(number_text)

#save the type of converted variable
data_type = type(actual_number)

#Print the save type to confirm the conversion
print(data_type)
# Out:
# <class 'int'>

# %% [markdown]
# product price calculator

# %%
#Prosduct Price Calulator
original_price = float(input("Enter Original Price:"))

#discount percentage
discount_percentage =float(input("Enter Discount %:"))

#Discount Amount
discount_amount = (discount_percentage/100*original_price)

#final Price
final_price = original_price-discount_amount

#Output
print(f"final price after  {discount_percentage}% discount is {final_price}")
# Out:
# Enter Original Price:1000
# Enter Discount %:20
# final price after  20.0% discount is 800.0
